# %% [markdown]
# ## DatApp Sonora
# #### Análisis y Reportes

# %%
# Reporte N°01: Clientes registrados en la base de datos

import pandas as pd
from conexion import engine

query = "SELECT * FROM cliente LIMIT 3"
df = pd.read_sql(query, engine)
df
# Out:
#    ruc_cliente          razon_social                  direccion   telefono
# 0  20123456789  Frecuencia Urbana FM  Av. Larco 123, Miraflores  987654321
# 1  20987654321          Rock Station        Jr. Unión 456, Lima  912345678
# 2  20334455661         Indie Records       Ca. Las Palmeras 112  933445566
